# %% [markdown]
# <a href="https://colab.research.google.com/github/HeesooHan/toy_pythons/blob/main/LoopWithCounter_hsh.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
first = 1

# %%
while first <= 5 :
  print (first)
  first = first + 1
print ("End")
# Out:
# 1
# 2
# 3
# 4
# 5
# End
