# %% [markdown]
# <a href="https://colab.research.google.com/github/HeesooHan/toy_pythons/blob/main/whiles_Heesoo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
first = 1

# %%
while first < 4 :
  print (first)
  print('in whiling')
  first = first + 1
print ("end")
# Out:
# 1
# in whiling
# 2
# in whiling
# 3
# in whiling
# end

# %% [markdown]
# # 두 번째 입력을 합니다.
